# %%
import pandas as pd

# %%
df = pd.read_excel('I-82676.xlsx', sheet_name='List of products')

# %%
df
# Out:
#          #   Quoted Mcule ID Quoted product  \
# 0        1  MCULE-8735313713    P-886337969
# 1        2  MCULE-4732071325    P-889751794
# 2        3  MCULE-6637239360    P-851822592
# 3        4  MCULE-1214245590    P-864063821
# 4        5  MCULE-7823943866      P-3562083
# ...    ...               ...            ...
# 1581  1582  MCULE-8706538802    P-889117656
# 1582  1583  MCULE-4677373694    P-889110547
# 1583  1584  MCULE-1628840134    P-579624920
# 1584  1585  MCULE-3684026487    P-868743761
# 1585  1586  MCULE-1587050384    P-889735613
#
#                                   Quoted product SMILES        Supplier  \
# 0     C1(N(=O)=O)=C(OC(=O)C2=CC=CC=C2C(F)(F)F)C=C(NC...        A2B Chem
# 1                            C1(=CC=C(C=C1OC)NC)C(OC)=O          AmBeed
# 2                        C1(C(C)=O)=CN=C(N=C1C)SCC(O)=O          AmBeed
# 3              [H][C@]12O[C@@](C3C=CC=CC=31)(C(=O)O)CC2  MedChemExpress
# ...
